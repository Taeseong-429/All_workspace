# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df_2016 = pd.read_csv(f'C:/app/TeamProject/mod_weather_Data/기상관측2016real_Fixed.csv', encoding = 'cp949', parse_dates=['일시'])
df_2017 = pd.read_csv(f'C:/app/TeamProject/mod_weather_Data/기상관측2017real_Fixed.csv', encoding = 'cp949', parse_dates=['일시'])
df_2018 = pd.read_csv(f'C:/app/TeamProject/mod_weather_Data/기상관측2018real_Fixed.csv', encoding = 'cp949', parse_dates=['일시'])

# %%
df_merge = pd.concat([df_2016, df_2017, df_2018])

# %%
df_merge
# Out:
#       Unnamed: 0          기상번호  시도코드         일시  평균기온(°C)  최저기온(°C)  최고기온(°C)  \
# 0              0  112016-01-01    11 2016-01-01     1.200    -3.300     4.000
# 1              1  112016-01-02    11 2016-01-02     5.700     1.000     9.500
# 2              2  112016-01-03    11 2016-01-03     6.500     5.100     9.400
# 3              3  112016-01-04    11 2016-01-04     2.000    -2.500     5.300
# 4              4  112016-01-05    11 2016-01-05    -2.700    -4.800     1.500
# ...          ...           ...   ...        ...       ...       ...       ...
# 6200        6200    4920181227    49 2018-12-27     3.575     1.350     7.475
# 6201        6201    4920181228    49 2018-12-28     1.550     0.100     3.300
# 6202        6202    4920181229    49 2018-12-29     2.800     0.825     4.975
# 6203        6203    4920181230    49 2018-12-30     3.300     1.500     4.800
# 6204        6204    4920181231    49 2018-12-31     4.750     3.050     6.625
#
# ...

# %%
df_merge.index = df_merge['일시']

# %%
df_merge
# Out:
#             Unnamed: 0          기상번호  시도코드         일시  평균기온(°C)  최저기온(°C)  \
# 일시
# 2016-01-01           0  112016-01-01    11 2016-01-01     1.200    -3.300
# 2016-01-02           1  112016-01-02    11 2016-01-02     5.700     1.000
# 2016-01-03           2  112016-01-03    11 2016-01-03     6.500     5.100
# 2016-01-04           3  112016-01-04    11 2016-01-04     2.000    -2.500
# 2016-01-05           4  112016-01-05    11 2016-01-05    -2.700    -4.800
# ...                ...           ...   ...        ...       ...       ...
# 2018-12-27        6200    4920181227    49 2018-12-27     3.575     1.350
# 2018-12-28        6201    4920181228    49 2018-12-28     1.550     0.100
# 2018-12-29        6202    4920181229    49 2018-12-29     2.800     0.825
# 2018-12-30        6203    4920181230    49 2018-12-30     3.300     1.500
# 2018-12-31        6204    4920181231    49 2018-12-31     4.750     3.050
#
#             최고기온(°C)  최다풍향(16방위)  평균 현지기압(hPa)  일 최심신적설(cm)  일강수량(mm)  \
# ...
