# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_com = pd.read_csv('C:/app/TeamProject/mod_weather_Data/미세먼지+기상관측.csv', encoding = 'cp949')

# %%
df_com.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18632 entries, 0 to 18631
# Data columns (total 16 columns):
# Unnamed: 0      18632 non-null int64
# 기상번호            18632 non-null int64
# 시도코드            18632 non-null int64
# 일시              18632 non-null int64
# 평균기온(°C)        18631 non-null float64
# 최저기온(°C)        18632 non-null float64
# 최고기온(°C)        18631 non-null float64
# 평균 풍속(m/s)      18629 non-null float64
# 최다풍향(16방위)      18629 non-null float64
# 평균 현지기압(hPa)    18631 non-null float64
# SO2             18632 non-null float64
# CO              18632 non-null float64
# O3              18632 non-null float64
# NO2             18632 non-null float64
# PM10            18632 non-null float64
# PM25            18510 non-null float64
# dtypes: float64(12), int64(4)
# memory usage: 2.3 MB

# %%
df_com_1 = df_com.drop(['Unnamed: 0'], axis = 1)
df_com_1 = df_com.

# %%
df_com_1
# Out:
#              기상번호  시도코드        일시  평균기온(°C)  최저기온(°C)  최고기온(°C)  평균 풍속(m/s)  \
# 0      1120160101    11  20160101     1.200    -3.300     4.000       1.600
# 1      1120160102    11  20160102     5.700     1.000     9.500       2.000
# 2      1120160103    11  20160103     6.500     5.100     9.400       1.800
# 3      1120160104    11  20160104     2.000    -2.500     5.300       3.100
# 4      1120160105    11  20160105    -2.700    -4.800     1.500       2.300
# ...           ...   ...       ...       ...       ...       ...         ...
# 18627  4920181227    49  20181227     3.575     1.350     7.475       5.925
# 18628  4920181228    49  20181228     1.550     0.100     3.300       6.200
# 18629  4920181229    49  20181229     2.800     0.825     4.975       5.050
# 18630  4920181230    49  20181230     3.300     1.500     4.800       4.350
# 18631  4920181231    49  20181231     4.750     3.050     6.625       3.775
#
# ...

# %%
df_com_1[df_com_1['평균 풍속(m/s)'].isnull()]
# Out:
#            기상번호  시도코드        일시  평균기온(°C)  최저기온(°C)  최고기온(°C)  평균 풍속(m/s)  \
# 652  1120171014    11  20171014      14.4       9.0      20.5         NaN
# 704  1120171205    11  20171205      -4.2      -8.2      -0.4         NaN
# 705  1120171206    11  20171206       0.2      -4.5       6.0         NaN
#
#      최다풍향(16방위)  평균 현지기압(hPa)       SO2        CO        O3       NO2  \
# 652         NaN        1015.5  0.004059  0.509338  0.019040  0.030654
# 704         NaN        1012.0  0.004849  0.412514  0.015788  0.025519
# 705         NaN        1011.7  0.004721  0.598156  0.005422  0.039630
#
#           PM10       PM25
# 652  25.602151  11.651007
# 704  23.846328  11.010256
# 705  34.958150  21.585324

# %%
import numpy

# %%
df_com_1_2016 = df_com_1.loc['20160101':'20161231']
# df_mk_sejong = df[df['지점명'].str.contains('대전|청주|천안', regex=True)]

# %%
print(df_com_1_2016)
# Out:
# Empty DataFrame
# Columns: [기상번호, 시도코드, 일시, 평균기온(°C), 최저기온(°C), 최고기온(°C), 평균 풍속(m/s), 최다풍향(16방위), 평균 현지기압(hPa), SO2, CO, O3, NO2, PM10, PM25]
# Index: []

# %%
df_pivot = df_com_1.pivot_table(values='평균기온(°C)', columns = '시도코드', index='['일시' == [20160101:20161231]')
# Out:
#   File "<ipython-input-34-4e80ad21b77b>", line 1
#     df_pivot = df_com_1.pivot_table(values='평균기온(°C)', columns = '시도코드', index='['일시' == [20160101:20161231]')
#                                                                                   ^
# SyntaxError: invalid syntax

# %%
df_pivot
# Out:
# 시도코드        11    26   27        28   29   30   31        36     41        42  \
# 일시
# 20160101   1.2   5.3  1.7  3.133333  3.2  1.6  4.0  1.633333  -0.30  0.530769
# 20160102   5.7   8.1  3.0  7.100000  6.5  6.6  5.6  6.233333   4.60  5.176923
# 20160103   6.5  11.4  4.9  5.366667  7.3  6.9  7.0  6.333333   4.40  4.915385
# 20160104   2.0  10.4  5.8  1.433333  6.4  5.1  7.7  4.466667   2.76  3.946154
# 20160105  -2.7   5.3  2.9 -1.833333  2.4 -0.6  3.9 -0.700000  -1.94 -1.069231
# ...        ...   ...  ...       ...  ...  ...  ...       ...    ...       ...
# 20181227 -10.1   0.5 -3.3 -9.100000 -3.2 -5.9 -1.6 -6.933333  -9.48 -7.800000
# 20181228 -10.5  -3.5 -5.7 -8.600000 -4.9 -8.6 -4.4 -9.333333 -10.84 -9.557143
# 20181229  -7.6  -2.2 -4.2 -6.133333 -3.3 -6.1 -3.1 -6.233333  -7.62 -8.035714
# 20181230  -6.8  -0.7 -3.6 -6.233333 -2.4 -5.4 -1.8 -6.133333  -8.62 -7.635714
# 20181231  -5.4   3.9 -1.3 -4.700000 -1.8 -4.7  2.2 -5.466667  -7.38 -5.785714
#
# ...

# %%
df_pivot.plot()
plt.legend(bbox_to_anchor=(0.8, 0., 0.5, 0.7))
# Out:
# c:\app\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 51068 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\app\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\app\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 51068 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\app\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0, flags=flags)
