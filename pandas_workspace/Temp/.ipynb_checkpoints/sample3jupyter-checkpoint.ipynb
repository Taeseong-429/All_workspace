# %%
import pandas as pd

# %%
df = pd.read_csv('../doit_pandas/data/gapminder.tsv', sep = '\t') # 이렇게 위로 올라갔다가 내려가는 방식으로 ! 
# Temp 폴더에서 pandas_workssapce로 올라갔다가 다시 내려오게 !

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
# country      1704 non-null object
# continent    1704 non-null object
# year         1704 non-null int64
# lifeExp      1704 non-null float64
# pop          1704 non-null int64
# gdpPercap    1704 non-null float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 80.0+ KB

# %%
# 열데이터 추출 문법 : df[ 'column name' ] or df[ ['col1', 'col2', ...] ] # 이런식으로 컬럼의 이름을 
# 부여해서 호출했다. 
# df[0]  XX
# df[ , ] 문법 오류남  XX 
# df[0, ] 문법 오류남 XX
# df[0,0] XXX

# %%
# df[0:5] # 0을 포함, 5는 포함X --> 0, 1, 2, 3, 4 OK
# df[:] # 모든 행을 뽑아라 OK
# df[0:0] # 0번째 인덱스를 뽑으라는 의미인데 아무것도 안나옴. Empty data Frame

# df[0,3,5] # 튜플은 소괄호 기호 생략할 수 있기 때문에 이거 튜플로 인식함.
# = df[ (0,3,5) ] 과 같은 표시임.
# df[ [0,3,5] ]  XX

# df[0:3 , ]  XX

# %%
type(df.loc) # 데이터에서 행데이터를 뽑아낼 때 사용.
# locaindex 라고 하는 것, 행의 위치를 지정해주는 지정자. 행데이터를 뽑아줌
# loc 속성은 인덱스로 행데이터를 뽑아냄 ..

# %%
type(df.iloc) # 데이터 프레임이 갖고 있는 인덱스. 같은 인덱스 인데
# 원하는 인덱스가 다름. 얘는 행번호를 씀 !!
# Out:
# pandas.core.indexing._iLocIndexer

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1704, step=1)

# %%
df # 위에 index가 이 아래꺼인덱스 말하나봄

# %%
df.loc[0] # 행데이터를 뽑아준건데 시리즈 처럼 보여줌..
# Out:
# country      Afghanistan
# continent           Asia
# year                1952
# lifeExp           28.801
# pop              8425333
# gdpPercap        779.445
# Name: 0, dtype: object

# %%
type(df.loc[0]) # 열뿐만 아니라 하나의 행도 시리즈임 !!
# Out:
# pandas.core.series.Series

# %%
df.loc[-1]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\app\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     375             try:
# --> 376                 return self._range.index(new_key)
#     377             except ValueError:
#
# ValueError: -1 is not in range
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-c8e3ddd1947a> in <module>
# ----> 1 df.loc[-1]
#
# c:\app\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1422
#    1423             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1424             return self._getitem_axis(maybe_callable, axis=axis)
#    1425
#    1426     def _is_scalar_access(self, key: Tuple):
#
# c:\app\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1848         # fall thru to straight lookup
#    1849         self._validate_key(key, axis)
# -> 1850         return self._get_label(key, axis=axis)
#    1851
#    1852
#
# c:\app\lib\site-packages\pandas\core\indexing.py in _get_label(self, label, axis)
#     158             raise IndexingError("no slices here, handle elsewhere")
#     159
# --> 160         return self.obj._xs(label, axis=axis)
#     161
#     162     def _get_loc(self, key: int, axis: int):
#
# c:\app\lib\site-packages\pandas\core\generic.py in xs(self, key, axis, level, drop_level)
#    3735             loc, new_index = self.index.get_loc_level(key, drop_level=drop_level)
#    3736         else:
# -> 3737             loc = self.index.get_loc(key)
#    3738
#    3739             if isinstance(loc, np.ndarray):
#
# c:\app\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     376                 return self._range.index(new_key)
#     377             except ValueError:
# --> 378                 raise KeyError(key)
#     379         return super().get_loc(key, method=method, tolerance=tolerance)
#     380
#
# KeyError: -1

# %%
df.loc[-1] XX
df.loc[0:3] XX
df.loc[0:0] XX
df.loc[  : ] # To extrack all rows 
df.loc[4: ] # To exract rows from 4th. index end rows
df.loc[ :10] #
# Out:
#   File "<ipython-input-24-754fa642556b>", line 1
#     df.loc[-1] XX
#                ^
# SyntaxError: invalid syntax

# %%
df.loc[1703]
df.loc[ df.shape[0] -1 ]
df.loc[ len(df) -1]
df.loc[len(df.index) -1]
df.loc[len(df.index) -1 ]
df.tail(1)
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 1703  Zimbabwe    Africa  2007   43.487  12311143  469.709298

# %%
# df.iloc # 행의 번호를 이용하여, 행 데이터 추출

type(df.iloc)
df.iloc[-1] # iloc는 행의 번호를 입력하다보니, -1 음수값도 가능 !! 
# - 인덱스 값 사용하듯이 사용 가능 ! 
# 지정된 숫자는, 데이터 프레임의 인덱스가 아니라, 그냥 행번호
df.iloc[-1]
df.iloc[ [1, 3, 5] ] # list : OK
# df.iloc[ {1, 3, 5} ] # set : XX
# df.iloc[ (1, 3, 5) ] # tuple : XX
# df.iloc[ P1: 'n1', 3: '2', 5: 'n3'} ] # dict : XX
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 5  Afghanistan      Asia  1977   38.438  14880372  786.113360
