# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re
import numpy as np
# %matplotlib inline

# %%
df = pd.read_csv('NHIS_Data_2016_Fixed.csv', encoding='cp949')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12540347 entries, 0 to 12540346
# Data columns (total 12 columns):
# 가입자일련번호     int64
# 진료내역일련번호    int64
# 성별코드        int64
# 연령대코드       int64
# 시도코드        int64
# 요양개시일자      int64
# 서식코드        int64
# 진료과목코드      int64
# 주상병코드       object
# 부상병코드       object
# 입내원일수       int64
# 총처방일수       int64
# dtypes: int64(10), object(2)
# memory usage: 1.1+ GB

# %%
df.head()
# Out:
#    가입자일련번호  진료내역일련번호  성별코드  연령대코드  시도코드    요양개시일자  서식코드  진료과목코드 주상병코드  부상병코드  \
# 0        1  34153116     2      2    45  20160817     3      14  L209  L0888
# 1        2  46374827     2      8    41  20160202     3       1  J209   J304
# 2        2   3115110     2      8    41  20160407     3       1  J209   J304
# 3        2  50348269     2      8    41  20160104     3       1  A099   K291
# 4        2  15822952     2      8    41  20160130     3      13   J40   J304
#
#    입내원일수  총처방일수
# 0      1      1
# 1      1      3
# 2      1      2
# 3      1      2
# 4      1      5

# %%
def ill(x):
    str = x[:3]
    de = re.findall(r'([A-Z])([_]?)(\d{2})?', str)
    for n, d, t in de:
        if t == '':
            t = 0
        if n == ('A' or 'B'):
            return 'AB'
        elif n == 'C' or (n == 'D' and int(t) <= 48):
            return 'CD48'
        elif n == 'D':
            return 'D50'
        elif n == 'H':
            if int(t) < 60:
                return 'H59'
            elif int(t) >= 60:
                return 'H60'
        elif n == ('S' or 'T'):
            return 'ST'
        elif n == ('V' or 'Y'):
            return 'VY'
        elif n == (n.startswith('F')):
            return 'F'
        else:
            return n
        pass
    pass

# %%
print(re.findall(r'([A-Z])([_]?)(\d{2}?)', "F10"))
# Out:
# [('F', '', '10')]

# %%
print(len('F_'[0:3]))
# Out:
# 2

# %%
def month_Fixed(vec):
    vec = vec[:6]
    return vec

# %%
def month(x):
    return re.compile('(\d{4})(\d{2})(\d{2})').sub('\g<1>-\g<2>', str(x))

# %%
df['요양개시일자']
# Out:
# 0           20160817
# 1           20160202
# 2           20160407
# 3           20160104
# 4           20160130
#               ...
# 12540342    20161125
# 12540343    20161117
# 12540344    20160905
# 12540345    20160712
# 12540346    20160815
# Name: 요양개시일자, Length: 12540347, dtype: int64

# %%
# df_ill_j2022.요양개시일자.astype('datetime64[ns]')
#df['요양개시일자(월별)']=df['요양개시일자'].apply(to_month())
# df['요양개시일자(월별)']=pd.to_string(df['요양개시일자'].apply(lambda x: x[:6]))
df['요양개시일자(월별)']=df['요양개시일자'].apply(month)

df_ill_j2022 = df[df['주상병코드'].str.contains('J01|J20|J21|J22', regex=True)]

# %%
df_ill_j2022.head()
# Out:
#     가입자일련번호  진료내역일련번호  성별코드  연령대코드  시도코드    요양개시일자  서식코드  진료과목코드  주상병코드 부상병코드  \
# 1         2  46374827     2      8    41  20160202     3       1   J209  J304
# 2         2   3115110     2      8    41  20160407     3       1   J209  J304
# 16        3  62655904     2      6    11  20160129     3       1   J209  J060
# 23        4  53030834     2      7    29  20160924     3      13  J0190  J304
# 34        5  56059845     1      2    41  20161208     3      11   J209  A099
#
#     입내원일수  총처방일수 요양개시일자(월별)
# 1       1      3    2016-02
# 2       1      2    2016-04
# 16      1      3    2016-01
# 23      1      7    2016-09
# 34      1      2    2016-12

# %%
df_ill_j2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1500028 entries, 1 to 12540337
# Data columns (total 13 columns):
# 가입자일련번호       1500028 non-null int64
# 진료내역일련번호      1500028 non-null int64
# 성별코드          1500028 non-null int64
# 연령대코드         1500028 non-null int64
# 시도코드          1500028 non-null int64
# 요양개시일자        1500028 non-null int64
# 서식코드          1500028 non-null int64
# 진료과목코드        1500028 non-null int64
# 주상병코드         1500028 non-null object
# 부상병코드         1500028 non-null object
# 입내원일수         1500028 non-null int64
# 총처방일수         1500028 non-null int64
# 요양개시일자(월별)    1500028 non-null object
# dtypes: int64(10), object(3)
# memory usage: 160.2+ MB

# %%
# Evolution of M Cases (2016)
df_ill_M = df[df['주상병코드'].str.contains('M', regex=True)]
df_count_month=df_ill_M.groupby('요양개시일자(월별)')['주상병코드'].count()


f, ax = plt.subplots(figsize = (20, 7))
sns.lineplot(x = df_count_month.index,
             y = '주상병코드',
              data = df_count_month.to_frame())
plt.grid(True)
plt.xlabel('Month', fontsize=12 )
plt.ylabel('Number of Cases', fontsize=12)
plt.title('Evolution of M Cases (2016)', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Evolution of M Cases (2016)')

# %%
# Evolution of I Cases (2016)
df_ill_I = df[df['주상병코드'].str.contains('I', regex=True)]
df_count_month=df_ill_I.groupby('요양개시일자(월별)')['주상병코드'].count()


f, ax = plt.subplots(figsize = (20, 7))
sns.lineplot(x = df_count_month.index,
             y = '주상병코드',
              data = df_count_month.to_frame())
plt.grid(True)
plt.xlabel('Month', fontsize=12 )
plt.ylabel('Number of Cases', fontsize=12)
plt.title('Evolution of I Cases (2016)', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Evolution of I Cases (2016)')

# %%
df_ill_full_J = df[df['주상병코드'].str.contains('J', regex=True)]
df_ill_full_J.to_csv('df_J_cases.csv', encoding = 'cp949')

# %%
# Evolution of all J-Type Cases (2016)
df_ill_full_J = df[df['주상병코드'].str.contains('J', regex=True)]

df_count_month=df_ill_full_J.groupby('요양개시일자(월별)')['주상병코드'].count()


f, ax = plt.subplots(figsize = (20, 7))
sns.lineplot(x = df_count_month.index,
             y = '주상병코드',
              data = df_count_month.to_frame())
plt.grid(True)
plt.xlabel('Month', fontsize=12 )
plt.ylabel('Number of Cases', fontsize=12)
plt.title('Evolution of all J-Type Cases (2016)', fontsize=16)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e6927912dcc8> in <module>
#       1 # Evolution of all J-Type Cases (2016)
# ----> 2 df_ill_full_J = df[df['주상병코드'].str.contains('J', regex=True)]
#       3
#       4 df_count_month=df_ill_full_J.groupby('요양개시일자(월별)')['주상병코드'].count()
#       5
#
# NameError: name 'df' is not defined

# %%
print('='*70)



f, ax = plt.subplots(figsize = (20, 7))
plt.grid()
sns.countplot(x = '요양개시일자',
              data = df_ill_j2022)
plt.show()

print('='*70)

df_count=df_ill_j2022.groupby('요양개시일자').count()

f, ax = plt.subplots(figsize = (20, 7))
plt.grid()
sns.lineplot(x = df_count.index,
             y = '가입자일련번호',
              data = df_count)
# Out:
# ======================================================================
# c:\app\python38\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 50836 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\app\python38\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 50577 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\app\python38\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 44060 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\app\python38\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\app\python38\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 51068 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\app\python38\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 51088 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\app\python38\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 50836 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\app\python38\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 50577 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\app\python38\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 44060 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\app\python38\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\app\python38\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 51068 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\app\python38\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 51088 missing from current font.
#   font.set_text(s, 0, flags=flags)
# ======================================================================
# c:\app\python38\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 44032 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\app\python38\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 51077 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\app\python38\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 47144 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\app\python38\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 48264 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\app\python38\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 54840 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\app\python38\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 44032 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\app\python38\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 51077 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\app\python38\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 47144 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\app\python38\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 48264 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\app\python38\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 54840 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
cities = ['Seoul', 'Busan', 'Daegu', 'Incheon', 'Gwangju', 'Daejeon', 'Ulsan', 'Sejong', 'Gyeongi-do', 'Gangwon-do', 'Chungcheongbuk-do',
           'Chungcheongnam-do', 'Jeollabuk-do', 'Jeollanam-do', 'Gyeongsangbuk-do', 'Gyeongsangnam-do', 'Jeju-do']

plt.subplots(figsize=(20, 7))
plt.grid(zorder = 1)
sns.countplot(x = '시도코드', orient = 'v', data = df_ill_full_J, zorder = 2, order = df_ill_full_J['시도코드'].value_counts().index )
plt.xticks(np.arange(17), cities, rotation = 45)
plt.xlabel('City Code', fontsize=12 )
plt.ylabel('Number of Cases', fontsize=12)
plt.title('Number of All J - Type Cases By City(2016)', fontsize=16)
plt.show()
plt.savefig('test')
#type(group_ill_j2022_frame.plot.bar())

# %%
df['질병코드'] = df['주상병코드'].apply(ill)

# %%
df.head()
# Out:
#    가입자일련번호  진료내역일련번호  성별코드  연령대코드  시도코드    요양개시일자  서식코드  진료과목코드 주상병코드  부상병코드  \
# 0        1  34153116     2      2    45  20160817     3      14  L209  L0888
# 1        2  46374827     2      8    41  20160202     3       1  J209   J304
# 2        2   3115110     2      8    41  20160407     3       1  J209   J304
# 3        2  50348269     2      8    41  20160104     3       1  A099   K291
# 4        2  15822952     2      8    41  20160130     3      13   J40   J304
#
#    입내원일수  총처방일수 요양개시일자(월별) 질병코드
# 0      1      1    2016-08    L
# 1      1      3    2016-02    J
# 2      1      2    2016-04    J
# 3      1      2    2016-01   AB
# 4      1      5    2016-01    J

# %%
plt.subplots(figsize=(20, 7))
plt.grid(zorder = 1)
sns.countplot(x = '질병코드', data = df, dodge=False, zorder=2, order = df['질병코드'].value_counts().index)
plt.xlabel('Illness Classification', fontsize = 12)
plt.ylabel('Number of Cases', fontsize = 12)
plt.title('Number of Cases by Illness Classification (2016)', fontsize = 16)
plt.show()
#type(group_ill_j2022_frame.plot.bar())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\app\python38\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '질병코드'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-4543c2b7b485> in <module>
#       1 plt.subplots(figsize=(20, 7))
#       2 plt.grid(zorder = 1)
# ----> 3 sns.countplot(x = '질병코드', data = df, dodge=False, zorder=2, order = df['질병코드'].value_counts().index)
#       4 plt.xlabel('Illness Classification', fontsize = 12)
#       5 plt.ylabel('Number of Cases', fontsize = 12)
#
# c:\app\python38\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2993             if self.columns.nlevels > 1:
#    2994                 return self._getitem_multilevel(key)
# -> 2995             indexer = self.columns.get_loc(key)
#    2996             if is_integer(indexer):
#    2997                 indexer = [indexer]
#
# c:\app\python38\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '질병코드'

# %%
pie_count = df.groupby('질병코드')['가입자일련번호'].count()
print(pie_count)
values = [210963,263485,231709,17225,530582,311089,193516,708997,364442,947636,3575262,747406,627772,2065364, 598544,24520,7458,12763, 253916, 674606, 76668,358,96066]
labels = ['AB', 'B', 'CD48', 'D50', 'E', 'F', 'G', 'H59', 'H60', 'I', 'J', 'K', 'L', 'M', 'N', 'O', 'P', 'Q', 'R', 'ST', 'T', 'U', 'Z' ]

plt.subplots(figsize=(20, 7))
plt.pie(x = values, labels= labels)
plt.title('Pie Graph by Illness Classification (2016)', fontsize = 16)
plt.show()
#type(group_ill_j2022_frame.plot.bar())
# Out:
# 질병코드
# AB       210963
# B        263485
# CD48     231709
# D50       17225
# E        530582
# F        311089
# G        193516
# H59      708997
# H60      364442
# I        947636
# J       3575262
# K        747406
# L        627772
# M       2065364
# N        598544
# O         24520
# P          7458
# Q         12763
# R        253916
# ST       674606
# T         76668
# U           358
# Z         96066
# Name: 가입자일련번호, dtype: int64

# %%
# Evolution of FCases (2016)
df_ill_F = df[df['주상병코드'].str.contains('F', regex=True)]
df_count_month=df_ill_F.groupby('요양개시일자(월별)')['주상병코드'].count()


f, ax = plt.subplots(figsize = (20, 7))
sns.lineplot(x = df_count_month.index,
             y = '주상병코드',
              data = df_count_month.to_frame())
plt.grid(True)
plt.xlabel('Month', fontsize=12 )
plt.ylabel('Number of Cases', fontsize=12)
plt.title('Evolution of I Cases (2016)', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Evolution of I Cases (2016)')
